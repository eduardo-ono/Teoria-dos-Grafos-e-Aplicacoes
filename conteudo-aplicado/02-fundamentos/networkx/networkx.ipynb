# %% [markdown]
# <div align="center">
#
# # NetworkX
#
# #### Prof. Eduardo Ono
#
# </div>
#
# &nbsp;

# %% [markdown]
# ## "Inferindo" Grafos

# %% [markdown]
# ## Descrição
#
# Dado um grafo já definido através da biblioteca NetworkX, podemos "inferir" (obter informações e resultados) utilizando métodos fornecidos pela mesma.
#
# &nbsp;

# %% [markdown]
# | Método | Descrição |
# | --- | --- |
# | edges() | Retorna o
# | nodes() | Retorna a lista de vértices do grafo.
# | num_of_nodes() |
# | num_of_edges |
# | size() | Retorna o número de arestas do grafo.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Personalizando Grafos

# %%
def nxdraw_opt(
        node_size=600,
        node_color='coral',
        with_labels=True
    ):
    return {
        'node_size': node_size,
        'node_color': node_color,
        'with_labels': with_labels
    }

G = nx.gnm_random_graph(8, 15)
nx.draw(G, **nxdraw_opt())
print('Vértices:', G.nodes())
print('Arestas', G.edges())
print('n =', G.number_of_nodes())
print('m =', G.number_of_edges())
# Out:
# Vértices: [0, 1, 2, 3, 4, 5, 6, 7]
# Arestas [(0, 7), (0, 5), (1, 5), (1, 4), (1, 6), (2, 6), (2, 7), (3, 5), (3, 7), (3, 4), (4, 6), (4, 7), (4, 5), (5, 6), (6, 7)]
# n = 8
# m = 15
