# %% [markdown]
# # Grafos
#
# __Prof. Eduardo Ono__
#
# &nbsp;

# %% [markdown]
# ## Resumo da Terminologia de Grafos
#
# | Tipo | Arestas | Múltiplas Arestas | Loops | Classe (NetworkX)
# | --- | --- | :-: | :-: | :-: |
# | Grafo simples | Não-Orientadas | Não | Não | Graph
# | Grafo Orientado Simples | Orientadas | Não | Não | DiGraph
# | Multigrafo | Não-orientadas | Sim | Não | MultiGraph
# | Multigrafo Orientado | Orientadas | Sim | Sim | MultiDiGraph
# | Pseudografo | Não-orientadas | Sim | Sim |
# | Grafos Mistos | Orientadas e Não-Orientadas | Sim | Sim |
#
# <p><small>Fonte: https://www.youtube.com/watch?v=0n45TjyoT_w</small></p>

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph() # Cria um grafo vazio
G.add_node('A')
G.add_node('B')
G.add_node('C')
G.add_node('D')
G.add_node('E')
nx.draw(G, node_size=600, node_color='coral', with_labels=True)

# %%
G.add_edge('A','B')
G.add_edge('A','C')
G.add_edge('B','C')
G.add_edge('B','E')
G.add_edge('C','D')
G.add_edge('C','E')
nx.draw(G, node_size=600, node_color='coral', with_labels=True)

# %%
options = {
    "font_size": 16,
    "node_size": 800,
    "node_color": 'coral',
    "with_labels": True,
}
nx.draw(G, **options)

# %%
V = ['A', 'B', 'C', 'D', 'E'] # Lista dos vértices
E = [('A', 'B'), ('A', 'C'), ('B', 'D'), ('B', 'E'), ('D', 'E'), ('C', 'E')] # Lista das arestas
G.add_nodes_from(V)
G.add_edges_from(E)
nx.draw_circular(G, **options)

# %% [markdown]
# ### Grau do Vértice

# %%
print(G.degree())
print(nx.degree(G))
print(nx.degree(G)['A'])
# Out:
# [('A', 2), ('B', 4), ('C', 4), ('D', 3), ('E', 3)]
# [('A', 2), ('B', 4), ('C', 4), ('D', 3), ('E', 3)]
# 2

# %% [markdown]
# <br>
#
# ## Referências
#
# | Thumb | Descrição |
# | :-: | --- |
# | [![img](https://img.youtube.com/vi/TobQPmjmkjQ/default.jpg)](https://www.youtube.com/watch?v=TobQPmjmkjQ) | <sup>[Prof. Dr. Petronio Silva]</sup><br>[__Redes Complexas - Grafos e a Biblioteca NetworkX__](https://www.youtube.com/watch?v=TobQPmjmkjQ)<br><sub>(1:43:25, YouTube, Fev/2022)</sub>
